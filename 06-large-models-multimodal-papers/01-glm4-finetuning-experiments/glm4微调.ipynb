# %%
# !ls
# Out:
# 0.41.1
# GLM-4
# chatglm3_6b_context.ipynb
# glm4微调.ipynb

# %%
# !pip install bitsandbytes>=0.41.1 peft

# %%
# 这一条需要修改peft==0.12.0
# 这一条需要修改peft==0.12.0
# !pip install -r GLM-4/finetune_demo/requirements.txt
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...
#   Using cached https://mirrors.aliyun.com/pypi/packages/60/2d/963b266bb8f88492d5ab4232d74292af8beb5b6fdae97902df9e284d4c32/datasets-2.20.0-py3-none-any.whl (547 kB)
# ...
#   Using cached https://mirrors.aliyun.com/pypi/packages/62/72/fcabddf222ec938c3cbd5616e5a72796938b5235897e07a1fcc2a8e7735e/peft-0.12.0-py3-none-any.whl (296 kB)
# ...
#   Using cached https://mirrors.aliyun.com/pypi/packages/2e/06/7315113506f1804b8ba4f77cb31905c62f7080452a0af2d13eaadaa83a08/deepspeed-0.14.4.tar.gz (1.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [26 lines of output]
# ...

# %%
# !pip list|grep dataset

# %%
# !pip install tiktoken
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...

# %%
# !pip install transformers==4.40.0
# 或者使用你代码里原本注释掉的这个版本试试：
# !pip install transformers==4.48.1 # 前提是这个版本能修好该 bug
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...
#   Using cached https://mirrors.aliyun.com/pypi/packages/09/c8/844d5518a6aeb4ffdc0cf0cae65ae13dbe5838306728c5c640b5a6e2a0c9/transformers-4.40.0-py3-none-any.whl (9.0 MB)
# ...
#   Using cached https://mirrors.aliyun.com/pypi/packages/a8/af/48ac8483240de756d2438c380746e7130d1c6f75802ef22f3c6d49982787/huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# ...
#   Using cached https://mirrors.aliyun.com/pypi/packages/48/04/2071c150f374aab6d5e92aaec38d0f3c368d227dd9e0469a1f0966ac68d1/tokenizers-0.19.1.tar.gz (321 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
# ...

# %%
# 1. 先将工作目录切换到微调脚本所在的文件夹
# %cd GLM-4/finetune_demo

# 2. 然后再执行微调命令 (此时 ./AdvertiseGen_fix/ 和 configs/lora.yaml 都能正确找到了)
# !python finetune.py ./AdvertiseGen_fix/ THUDM/glm-4-9b-chat configs/lora.yaml
# Out:
# D:\ai-study\day28\GLM-4\finetune_demo

# %%
import os

# 使用你本地的绝对路径，一步到位切换到微调脚本所在目录
os.chdir(r"D:\ai-study\day28\GLM-4\finetune_demo")

# 打印出来确认一下是否切换成功
print("当前工作目录已重置为:", os.getcwd())

# %%
# !pip install ruamel.yaml

# %%
# !python finetune.py ./AdvertiseGen_fix/ THUDM/glm-4-9b-chat configs/lora.yaml

# %%
#默认使用的原始大模型路径就是在系统下，这里跟的是微调后的权重
#如果要预测其他内容，直接修改inference.py中的messages即可，也可以修改代码，传参argv
# !python inference.py output/checkpoint-3000

# %%
# !python inference.py
