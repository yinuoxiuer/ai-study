# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/THUDM/GLM-4.git
# Out:
# fatal: destination path 'GLM-4' already exists and is not an empty directory.

# %%
# !ls
# Out:
# drive  GLM-4  sample_data

# %%
# !ls /content/drive/MyDrive/
# Out:
#  CoinbaseWalletBackups
# 'CoinbaseWalletBackups (1)'
# 'Colab Notebooks'
#  GLM-4
# 'Google AI Studio'
# 'Transformer 超参数配置对比.gsheet'
#  优化器激活函数最佳搭档.gsheet
#  在大纲中插入我的进修word中的图片.gsheet
#  天眼查集成电路布图抓取脚本
#  电催化剂学习基础知识指南.gdoc
#  电催化科学：硕士研究生从入门到精通实战手册.gdoc

# %%
# 这里的微调数据集格式与glm3的不一样，请使用给大家的数据集
# %cd GLM-4
# !cp -r /content/drive/MyDrive/AdvertiseGen_fix/ finetune_demo/
# %cd ..
# !mv GLM-4/ /content/drive/MyDrive/
# Out:
# /content/GLM-4
# cp: cannot stat '/content/drive/MyDrive/AdvertiseGen_fix/': No such file or directory
# /content
# mv: inter-device move failed: 'GLM-4/' to '/content/drive/MyDrive/GLM-4'; unable to remove target: Directory not empty

# %%
# %cd /content/drive/MyDrive/GLM-4/finetune_demo/
# Out:
# /content/drive/MyDrive/GLM-4/finetune_demo

# %%
# 这一条需要修改peft==0.12.0
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: jieba==0.42.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (0.42.1)
# Requirement already satisfied: datasets==2.20.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.20.0)
# Requirement already satisfied: peft==0.12.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (0.12.0)
# Requirement already satisfied: deepspeed==0.14.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (0.14.4)
# Requirement already satisfied: nltk==3.8.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (3.8.1)
# Requirement already satisfied: rouge_chinese==1.0.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (1.0.3)
# Requirement already satisfied: ruamel.yaml==0.18.6 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.18.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0->-r requirements.txt (line 2)) (3.24.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0->-r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0->-r requirements.txt (line 2)) (18.1.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0->-r requirements.txt (line 2)) (0.7)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0->-r requirements.txt (line 2)) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0->-r requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0->-r requirements.txt (line 2)) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0->-r requirements.txt (line 2)) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0->-r requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0->-r requirements.txt (line 2)) (0.70.16)
# Requirement already satisfied: fsspec<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets==2.20.0->-r requirements.txt (line 2)) (2024.5.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0->-r requirements.txt (line 2)) (3.13.3)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0->-r requirements.txt (line 2)) (0.36.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0->-r requirements.txt (line 2)) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets==2.20.0->-r requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft==0.12.0->-r requirements.txt (line 3)) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.12.0->-r requirements.txt (line 3)) (2.10.0+cu128)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from peft==0.12.0->-r requirements.txt (line 3)) (4.45.2)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.12.0->-r requirements.txt (line 3)) (1.12.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from peft==0.12.0->-r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: hjson in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.14.4->-r requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.14.4->-r requirements.txt (line 4)) (1.13.0)
# Requirement already satisfied: nvidia-ml-py in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.14.4->-r requirements.txt (line 4)) (13.590.48)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.14.4->-r requirements.txt (line 4)) (9.0.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.14.4->-r requirements.txt (line 4)) (2.12.3)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk==3.8.1->-r requirements.txt (line 5)) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk==3.8.1->-r requirements.txt (line 5)) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk==3.8.1->-r requirements.txt (line 5)) (2025.11.3)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from rouge_chinese==1.0.3->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.12/dist-packages (from ruamel.yaml==0.18.6->-r requirements.txt (line 7)) (0.2.15)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.20.0->-r requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.20.0->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.20.0->-r requirements.txt (line 2)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.20.0->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.20.0->-r requirements.txt (line 2)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.20.0->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.20.0->-r requirements.txt (line 2)) (1.22.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21.2->datasets==2.20.0->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21.2->datasets==2.20.0->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==2.20.0->-r requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==2.20.0->-r requirements.txt (line 2)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==2.20.0->-r requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==2.20.0->-r requirements.txt (line 2)) (2026.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (1.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==2.20.0->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==2.20.0->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==2.20.0->-r requirements.txt (line 2)) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->deepspeed==0.14.4->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->deepspeed==0.14.4->-r requirements.txt (line 4)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->deepspeed==0.14.4->-r requirements.txt (line 4)) (0.4.2)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.12/dist-packages (from transformers->peft==0.12.0->-r requirements.txt (line 3)) (0.20.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->peft==0.12.0->-r requirements.txt (line 3)) (3.0.3)

# %%
# !pip list|grep dataset
# Out:
# datasets                                 2.20.0
# tensorflow-datasets                      4.9.9
# vega-datasets                            0.9.0

# %%
# !pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (0.12.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (2026.1.4)

# %%
# !pip install "transformers==4.45.2"
# Out:
# Requirement already satisfied: transformers==4.45.2 in /usr/local/lib/python3.12/dist-packages (4.45.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.2) (3.24.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.2) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.2) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.2) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.2) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.2) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.2) (2.32.4)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.2) (0.7.0)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.2) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.2) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.2) (2024.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.2) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.2) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.45.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.45.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.45.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.45.2) (2026.1.4)

# %%
# !python finetune.py ./AdvertiseGen_fix/ THUDM/glm-4-9b-chat configs/lora.yaml
# !python finetune.py  ./AdvertiseGen_fix/  THUDM/glm-4-9b-chat  configs/lora.yaml # For Chat Fine-tune
# python finetune_vision.py  data/CogVLM-311K/  THUDM/glm-4v-9b configs/lora.yaml # For VQA Fine-tune
# Out:
# 2026-02-26 12:29:31.975522: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772108971.996830   10167 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772108972.003868   10167 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772108972.022165   10167 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772108972.022192   10167 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772108972.022196   10167 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772108972.022199   10167 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-26 12:29:32.026869: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading checkpoint shards: 100% 10/10 [00:03<00:00,  3.11it/s]
# trainable params: 2,785,280 || all params: 9,402,736,640 || trainable%: 0.0296
# train_dataset: Dataset({
#     features: ['input_ids', 'labels'],
#     num_rows: 114599
# })
# val_dataset: Dataset({
#     features: ['input_ids', 'output_ids'],
#     num_rows: 1070
# })
# test_dataset: Dataset({
#     features: ['input_ids', 'output_ids'],
#     num_rows: 1070
# })
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /content/drive/MyDrive/GLM-4/finetune_demo/finetune.py:457 in main           │
# │                                                                              │
# │   454 │   │   151329, 151336, 151338                                         │
# │   455 │   ]                                                                  │
# │   456 │                                                                      │
# │ ❱ 457 │   trainer = Seq2SeqTrainer(                                          │
# │   458 │   │   model=model,                                                   │
# │   459 │   │   args=ft_config.training_args,                                  │
# │   460 │   │   data_collator=DataCollatorForSeq2Seq(                          │
# │                                                                              │
# │ /usr/local/lib/python3.12/dist-packages/transformers/trainer_seq2seq.py:57   │
# │ in __init__                                                                  │
# │                                                                              │
# │    54 │   │   optimizers: Tuple[torch.optim.Optimizer, torch.optim.lr_schedu │
# │    55 │   │   preprocess_logits_for_metrics: Optional[Callable[[torch.Tensor │
# │    56 │   ):                                                                 │
# │ ❱  57 │   │   super().__init__(                                              │
# │    58 │   │   │   model=model,                                               │
# │    59 │   │   │   args=args,                                                 │
# │    60 │   │   │   data_collator=data_collator,                               │
# │                                                                              │
# │ /usr/local/lib/python3.12/dist-packages/transformers/trainer.py:554 in       │
# │ __init__                                                                     │
# │                                                                              │
# │    551 │   │   │   self.place_model_on_device                                │
# │    552 │   │   │   and not getattr(model, "quantization_method", None) == Qu │
# │    553 │   │   ):                                                            │
# │ ❱  554 │   │   │   self._move_model_to_device(model, args.device)            │
# │    555 │   │                                                                 │
# │    556 │   │   # Force n_gpu to 1 to avoid DataParallel as MP will manage th │
# │    557 │   │   if self.is_model_parallel:                                    │
# │                                                                              │
# │ /usr/local/lib/python3.12/dist-packages/transformers/trainer.py:802 in       │
# │ _move_model_to_device                                                        │
# │                                                                              │
# │    799 │   │   self.callback_handler.remove_callback(callback)               │
# │    800 │                                                                     │
# │    801 │   def _move_model_to_device(self, model, device):                   │
# │ ❱  802 │   │   model = model.to(device)                                      │
# │    803 │   │   # Moving a model to an XLA device disconnects the tied weight │
# │    804 │   │   if self.args.parallel_mode == ParallelMode.TPU and hasattr(mo │
# │    805 │   │   │   model.tie_weights()                                       │
# │                                                                              │
# │ /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1381 in   │
# │ to                                                                           │
# │                                                                              │
# │   1378 │   │   │   │   else:                                                 │
# │   1379 │   │   │   │   │   raise                                             │
# │   1380 │   │                                                                 │
# │ ❱ 1381 │   │   return self._apply(convert)                                   │
# │   1382 │                                                                     │
# │   1383 │   def register_full_backward_pre_hook(                              │
# │   1384 │   │   self,                                                         │
# │                                                                              │
# │ /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:933 in    │
# │ _apply                                                                       │
# │                                                                              │
# │    930 │   def _apply(self, fn, recurse=True):                               │
# │    931 │   │   if recurse:                                                   │
# │    932 │   │   │   for module in self.children():                            │
# │ ❱  933 │   │   │   │   module._apply(fn)                                     │
# │    934 │   │                                                                 │
# │    935 │   │   from torch._subclasses.fake_tensor import FakeTensor          │
# │    936                                                                       │
# │                                                                              │
# │ /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:933 in    │
# │ _apply                                                                       │
# │                                                                              │
# │    930 │   def _apply(self, fn, recurse=True):                               │
# │    931 │   │   if recurse:                                                   │
# │    932 │   │   │   for module in self.children():                            │
# │ ❱  933 │   │   │   │   module._apply(fn)                                     │
# │    934 │   │                                                                 │
# │    935 │   │   from torch._subclasses.fake_tensor import FakeTensor          │
# │    936                                                                       │
# │                                                                              │
# │ /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:933 in    │
# │ _apply                                                                       │
# │                                                                              │
# │    930 │   def _apply(self, fn, recurse=True):                               │
# │    931 │   │   if recurse:                                                   │
# │    932 │   │   │   for module in self.children():                            │
# │ ❱  933 │   │   │   │   module._apply(fn)                                     │
# │    934 │   │                                                                 │
# │    935 │   │   from torch._subclasses.fake_tensor import FakeTensor          │
# │    936                                                                       │
# │                                                                              │
# │ /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:933 in    │
# │ _apply                                                                       │
# │                                                                              │
# │    930 │   def _apply(self, fn, recurse=True):                               │
# │    931 │   │   if recurse:                                                   │
# │    932 │   │   │   for module in self.children():                            │
# │ ❱  933 │   │   │   │   module._apply(fn)                                     │
# │    934 │   │                                                                 │
# │    935 │   │   from torch._subclasses.fake_tensor import FakeTensor          │
# │    936                                                                       │
# │                                                                              │
# │ /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:933 in    │
# │ _apply                                                                       │
# │                                                                              │
# │    930 │   def _apply(self, fn, recurse=True):                               │
# │    931 │   │   if recurse:                                                   │
# │    932 │   │   │   for module in self.children():                            │
# │ ❱  933 │   │   │   │   module._apply(fn)                                     │
# │    934 │   │                                                                 │
# │    935 │   │   from torch._subclasses.fake_tensor import FakeTensor          │
# │    936                                                                       │
# │                                                                              │
# │ /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:933 in    │
# │ _apply                                                                       │
# │                                                                              │
# │    930 │   def _apply(self, fn, recurse=True):                               │
# │    931 │   │   if recurse:                                                   │
# │    932 │   │   │   for module in self.children():                            │
# │ ❱  933 │   │   │   │   module._apply(fn)                                     │
# │    934 │   │                                                                 │
# │    935 │   │   from torch._subclasses.fake_tensor import FakeTensor          │
# │    936                                                                       │
# │                                                                              │
# │ /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:933 in    │
# │ _apply                                                                       │
# │                                                                              │
# │    930 │   def _apply(self, fn, recurse=True):                               │
# │    931 │   │   if recurse:                                                   │
# │    932 │   │   │   for module in self.children():                            │
# │ ❱  933 │   │   │   │   module._apply(fn)                                     │
# │    934 │   │                                                                 │
# │    935 │   │   from torch._subclasses.fake_tensor import FakeTensor          │
# │    936                                                                       │
# │                                                                              │
# │ /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:933 in    │
# │ _apply                                                                       │
# │                                                                              │
# │    930 │   def _apply(self, fn, recurse=True):                               │
# │    931 │   │   if recurse:                                                   │
# │    932 │   │   │   for module in self.children():                            │
# │ ❱  933 │   │   │   │   module._apply(fn)                                     │
# │    934 │   │                                                                 │
# │    935 │   │   from torch._subclasses.fake_tensor import FakeTensor          │
# │    936                                                                       │
# │                                                                              │
# │ /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:964 in    │
# │ _apply                                                                       │
# │                                                                              │
# │    961 │   │   │   # track autograd history of `param_applied`, so we have t │
# │    962 │   │   │   # `with torch.no_grad():`                                 │
# │    963 │   │   │   with torch.no_grad():                                     │
# │ ❱  964 │   │   │   │   param_applied = fn(param)                             │
# │    965 │   │   │   p_should_use_set_data = compute_should_use_set_data(param │
# │    966 │   │   │                                                             │
# │    967 │   │   │   # subclasses may have multiple child tensors so we need t │
# │                                                                              │
# │ /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1367 in   │
# │ convert                                                                      │
# │                                                                              │
# │   1364 │   │   │   │   │   │   non_blocking,                                 │
# │   1365 │   │   │   │   │   │   memory_format=convert_to_format,              │
# │   1366 │   │   │   │   │   )                                                 │
# │ ❱ 1367 │   │   │   │   return t.to(                                          │
# │   1368 │   │   │   │   │   device,                                           │
# │   1369 │   │   │   │   │   dtype if t.is_floating_point() or t.is_complex()  │
# │   1370 │   │   │   │   │   non_blocking,                                     │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# OutOfMemoryError: CUDA out of memory. Tried to allocate 108.00 MiB. GPU 0 has a
# total capacity of 14.56 GiB of which 69.81 MiB is free. Including non-PyTorch
# memory, this process has 14.49 GiB memory in use. Of the allocated memory 14.39
# GiB is allocated by PyTorch, and 1.85 MiB is reserved by PyTorch but
# unallocated. If reserved but unallocated memory is large try setting
# PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See
# documentation for Memory Management
# (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
import os
os.listdir('output/checkpoint-3000')
# Out:
# ['adapter_config.json',
#  'training_args.bin',
#  'rng_state.pth',
#  'adapter_model.safetensors',
#  'trainer_state.json',
#  'optimizer.pt',
#  'README.md',
#  'scheduler.pt']

# %%
#默认使用的原始大模型路径就是在系统下，这里跟的是微调后的权重
#如果要预测其他内容，直接修改inference.py中的messages即可，也可以修改代码，传参argv
# !python inference.py output/checkpoint-3000
# Out:
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /usr/lib/python3.12/importlib/metadata/__init__.py:397 in from_name          │
# │                                                                              │
# │   394 │   │   if not name:                                                   │
# │   395 │   │   │   raise ValueError("A distribution name is required.")       │
# │   396 │   │   try:                                                           │
# │ ❱ 397 │   │   │   return next(cls.discover(name=name))                       │
# │   398 │   │   except StopIteration:                                          │
# │   399 │   │   │   raise PackageNotFoundError(name)                           │
# │   400                                                                        │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# StopIteration
#
# During handling of the above exception, another exception occurred:
#
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /content/drive/MyDrive/GLM-4/finetune_demo/inference.py:126 in main          │
# │                                                                              │
# │   123 │   #     }                                                            │
# │   124 │   # ]                                                                │
# │   125 │                                                                      │
# │ ❱ 126 │   model, tokenizer = load_model_and_tokenizer(model_dir)             │
# │   127 │   inputs = tokenizer.apply_chat_template(                            │
# │   128 │   │   messages,                                                      │
# │   129 │   │   add_generation_prompt=True,                                    │
# │                                                                              │
# │ /content/drive/MyDrive/GLM-4/finetune_demo/inference.py:22 in                │
# │ load_model_and_tokenizer                                                     │
# │                                                                              │
# │    19 │   model_dir = Path(model_dir).expanduser().resolve()                 │
# │    20 │                                                                      │
# │    21 │   # --- 新增：定义 4bit 量化配置，专为 12GB 显存保驾护航 ---         │
# │ ❱  22 │   q_config = BitsAndBytesConfig(                                     │
# │    23 │   │   load_in_4bit=True,                                             │
# │    24 │   │   bnb_4bit_quant_type="nf4",                                     │
# │    25 │   │   bnb_4bit_use_double_quant=True,                                │
# │                                                                              │
# │ /usr/local/lib/python3.12/dist-packages/transformers/utils/quantization_conf │
# │ ig.py:402 in __init__                                                        │
# │                                                                              │
# │    399 │   │   if kwargs:                                                    │
# │    400 │   │   │   logger.warning(f"Unused kwargs: {list(kwargs.keys())}. Th │
# │    401 │   │                                                                 │
# │ ❱  402 │   │   self.post_init()                                              │
# │    403 │                                                                     │
# │    404 │   @property                                                         │
# │    405 │   def load_in_4bit(self):                                           │
# │                                                                              │
# │ /usr/local/lib/python3.12/dist-packages/transformers/utils/quantization_conf │
# │ ig.py:460 in post_init                                                       │
# │                                                                              │
# │    457 │   │   if not isinstance(self.bnb_4bit_use_double_quant, bool):      │
# │    458 │   │   │   raise TypeError("bnb_4bit_use_double_quant must be a bool │
# │    459 │   │                                                                 │
# │ ❱  460 │   │   if self.load_in_4bit and not version.parse(importlib.metadata │
# │    461 │   │   │   "0.39.0"                                                  │
# │    462 │   │   ):                                                            │
# │    463 │   │   │   raise ValueError(                                         │
# │                                                                              │
# │ /usr/lib/python3.12/importlib/metadata/__init__.py:889 in version            │
# │                                                                              │
# │   886 │   :return: The version string for the package as defined in the pack │
# │   887 │   │   "Version" metadata key.                                        │
# │   888 │   """                                                                │
# │ ❱ 889 │   return distribution(distribution_name).version                     │
# │   890                                                                        │
# │   891                                                                        │
# │   892 _unique = functools.partial(                                           │
# │                                                                              │
# │ /usr/lib/python3.12/importlib/metadata/__init__.py:862 in distribution       │
# │                                                                              │
# │   859 │   :param distribution_name: The name of the distribution package as  │
# │   860 │   :return: A ``Distribution`` instance (or subclass thereof).        │
# │   861 │   """                                                                │
# │ ❱ 862 │   return Distribution.from_name(distribution_name)                   │
# │   863                                                                        │
# │   864                                                                        │
# │   865 def distributions(**kwargs):                                           │
# │                                                                              │
# │ /usr/lib/python3.12/importlib/metadata/__init__.py:399 in from_name          │
# │                                                                              │
# │   396 │   │   try:                                                           │
# │   397 │   │   │   return next(cls.discover(name=name))                       │
# │   398 │   │   except StopIteration:                                          │
# │ ❱ 399 │   │   │   raise PackageNotFoundError(name)                           │
# │   400 │                                                                      │
# │   401 │   @classmethod                                                       │
# │   402 │   def discover(cls, **kwargs):                                       │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# PackageNotFoundError: No package metadata was found for bitsandbytes
